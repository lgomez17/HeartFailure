# %%
import pandas as pd
from path import Path
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
# Load CSV dataset and start cleaning the data 
hf_data = pd.read_csv("heart.csv")

# %%
hf_data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
hf_data.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
hf_subset = hf_data[['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
       'RestingECG', 'MaxHR', 'ExerciseAngina','HeartDisease']]
hf_subset
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  HeartDisease
# 0      172              N             0
# 1      156              N             1
# 2       98              N             0
# 3      108              Y             1
# 4      122              N             0
# ..     ...            ...           ...
# 913    132              N             1
# 914    141              N             1
# 915    115              Y             1
# 916    174              N             1
# 917    173              N             0
#
# [918 rows x 10 columns]

# %%
hf_subset.columns = [
    'Age', 
    'Sex', 
    'Chest Pain Type', 
    'Resting Blood Pressure', 
    'Cholesterol', 
    'Fasting Blood Sugar',
    'Resting ECG', 
    'Max Heart Rate', 
    'Exercise Angina',
    'Heart Disease'   
]
hf_subset
# Out:
#      Age Sex Chest Pain Type  Resting Blood Pressure  Cholesterol  \
# 0     40   M             ATA                     140          289
# 1     49   F             NAP                     160          180
# 2     37   M             ATA                     130          283
# 3     48   F             ASY                     138          214
# 4     54   M             NAP                     150          195
# ..   ...  ..             ...                     ...          ...
# 913   45   M              TA                     110          264
# 914   68   M             ASY                     144          193
# 915   57   M             ASY                     130          131
# 916   57   F             ATA                     130          236
# 917   38   M             NAP                     138          175
#
#      Fasting Blood Sugar Resting ECG  Max Heart Rate Exercise Angina  \
# 0                      0      Normal             172               N
# 1                      0      Normal             156               N
# 2                      0          ST              98               N
# 3                      0      Normal             108               Y
# 4                      0      Normal             122               N
# ..                   ...         ...             ...             ...
# 913                    0      Normal             132               N
# 914                    1      Normal             141               N
# 915                    0      Normal             115               Y
# 916                    0         LVH             174               N
# 917                    0      Normal             173               N
#
#      Heart Disease
# 0                0
# 1                1
# 2                0
# 3                1
# 4                0
# ..             ...
# 913              1
# 914              1
# 915              1
# 916              1
# 917              0
#
# [918 rows x 10 columns]

# %%
hf_subset.to_html("hfstats.html")

# %%
hf_subset.describe()
# Out:
#               Age  Resting Blood Pressure  Cholesterol  Fasting Blood Sugar  \
# count  918.000000              918.000000   918.000000           918.000000
# mean    53.510893              132.396514   198.799564             0.233115
# std      9.432617               18.514154   109.384145             0.423046
# min     28.000000                0.000000     0.000000             0.000000
# 25%     47.000000              120.000000   173.250000             0.000000
# 50%     54.000000              130.000000   223.000000             0.000000
# 75%     60.000000              140.000000   267.000000             0.000000
# max     77.000000              200.000000   603.000000             1.000000
#
#        Max Heart Rate  Heart Disease
# count      918.000000     918.000000
# mean       136.809368       0.553377
# std         25.460334       0.497414
# min         60.000000       0.000000
# 25%        120.000000       0.000000
# 50%        138.000000       1.000000
# 75%        156.000000       1.000000
# max        202.000000       1.000000

# %%
hf_subset[hf_subset["Heart Disease"]>=1]
# Out:
#      Age Sex Chest Pain Type  Resting Blood Pressure  Cholesterol  \
# 1     49   F             NAP                     160          180
# 3     48   F             ASY                     138          214
# 8     37   M             ASY                     140          207
# 11    58   M             ATA                     136          164
# 13    49   M             ASY                     140          234
# ..   ...  ..             ...                     ...          ...
# 912   57   F             ASY                     140          241
# 913   45   M              TA                     110          264
# 914   68   M             ASY                     144          193
# 915   57   M             ASY                     130          131
# 916   57   F             ATA                     130          236
#
#      Fasting Blood Sugar Resting ECG  Max Heart Rate Exercise Angina  \
# 1                      0      Normal             156               N
# 3                      0      Normal             108               Y
# 8                      0      Normal             130               Y
# 11                     0          ST              99               Y
# 13                     0      Normal             140               Y
# ..                   ...         ...             ...             ...
# 912                    0      Normal             123               Y
# 913                    0      Normal             132               N
# 914                    1      Normal             141               N
# 915                    0      Normal             115               Y
# 916                    0         LVH             174               N
#
#      Heart Disease
# 1                1
# 3                1
# 8                1
# 11               1
# 13               1
# ..             ...
# 912              1
# 913              1
# 914              1
# 915              1
# 916              1
#
# [508 rows x 10 columns]

# %%
pd.DataFrame(hf_subset["Age"].value_counts())
# Out:
#     Age
# 54   51
# 58   42
# 55   41
# 57   38
# 56   38
# 52   36
# 62   35
# 59   35
# 51   35
# 53   33
# 60   32
# 48   31
# 61   31
# 63   30
# 50   25
# 43   24
# 46   24
# 41   24
# 64   22
# 49   21
# 65   21
# 47   19
# 44   19
# 45   18
# 42   18
# 38   16
# 67   15
# 39   15
# 69   13
# 40   13
# 66   13
# 35   11
# 37   11
# 68   10
# 34    7
# 74    7
# 70    7
# 36    6
# 32    5
# 71    5
# 72    4
# 75    3
# 29    3
# 76    2
# 77    2
# 33    2
# 31    2
# 73    1
# 30    1
# 28    1

# %%
pd.DataFrame(hf_subset["Chest Pain Type"].value_counts())
# Out:
#      Chest Pain Type
# ASY              496
# NAP              203
# ATA              173
# TA                46

# %%
pd.DataFrame(hf_subset["Resting ECG"].value_counts())
# Out:
#         Resting ECG
# Normal          552
# LVH             188
# ST              178

# %%
pd.DataFrame(hf_subset["Heart Disease"].value_counts())
# Out:
#    Heart Disease
# 1            508
# 0            410

# %%
pd.DataFrame(hf_subset["Sex"].value_counts())
# Out:
#    Sex
# M  725
# F  193

# %%
# Stage 2 hypertension 
hf_subset[hf_subset["Resting Blood Pressure"]>=140]
# Out:
#      Age Sex Chest Pain Type  Resting Blood Pressure  Cholesterol  \
# 0     40   M             ATA                     140          289
# 1     49   F             NAP                     160          180
# 4     54   M             NAP                     150          195
# 8     37   M             ASY                     140          207
# 13    49   M             ASY                     140          234
# ..   ...  ..             ...                     ...          ...
# 905   67   M             NAP                     152          212
# 908   63   M             ASY                     140          187
# 911   59   M             ASY                     164          176
# 912   57   F             ASY                     140          241
# 914   68   M             ASY                     144          193
#
#      Fasting Blood Sugar Resting ECG  Max Heart Rate Exercise Angina  \
# 0                      0      Normal             172               N
# 1                      0      Normal             156               N
# 4                      0      Normal             122               N
# 8                      0      Normal             130               Y
# 13                     0      Normal             140               Y
# ..                   ...         ...             ...             ...
# 905                    0         LVH             150               N
# 908                    0         LVH             144               Y
# 911                    1         LVH              90               N
# 912                    0      Normal             123               Y
# 914                    1      Normal             141               N
#
#      Heart Disease
# 0                0
# 1                1
# 4                0
# 8                1
# 13               1
# ..             ...
# 905              1
# 908              1
# 911              1
# 912              1
# 914              1
#
# [327 rows x 10 columns]

# %%
# Hypertension crisis
hf_subset[hf_subset["Resting Blood Pressure"]>=180]
# Out:
#      Age Sex Chest Pain Type  Resting Blood Pressure  Cholesterol  \
# 109   39   M             ATA                     190          241
# 123   58   F             ATA                     180          393
# 189   53   M             ASY                     180          285
# 190   46   M             ASY                     180          280
# 241   54   M             ASY                     200          198
# 274   45   F             ATA                     180          295
# 275   59   M             NAP                     180          213
# 278   57   F             ASY                     180          347
# 365   64   F             ASY                     200            0
# 372   63   M             ASY                     185            0
# 399   61   M             NAP                     200            0
# 411   54   M             ASY                     180            0
# 423   60   M             NAP                     180            0
# 585   57   M             ATA                     180          285
# 592   61   M             ASY                     190          287
# 725   55   F             ASY                     180          327
# 732   56   F             ASY                     200          288
# 759   54   M             ATA                     192          283
# 780   64   F             ASY                     180          325
# 855   68   M             NAP                     180          274
#
#      Fasting Blood Sugar Resting ECG  Max Heart Rate Exercise Angina  \
# 109                    0      Normal             106               N
# 123                    0      Normal             110               Y
# 189                    0          ST             120               Y
# 190                    0          ST             120               N
# 241                    0      Normal             142               Y
# 274                    0      Normal             180               N
# 275                    0      Normal             100               N
# 278                    0          ST             126               Y
# 365                    0      Normal             140               Y
# 372                    0      Normal              98               Y
# 399                    1          ST              70               N
# 411                    1      Normal             150               N
# 423                    0          ST             140               Y
# 585                    1          ST             120               N
# 592                    1         LVH             150               Y
# 725                    0          ST             117               Y
# 732                    1         LVH             133               Y
# 759                    0         LVH             195               N
# 780                    0      Normal             154               Y
# 855                    1         LVH             150               Y
#
#      Heart Disease
# 109              0
# 123              1
# 189              1
# 190              0
# 241              1
# 274              0
# 275              0
# 278              0
# 365              1
# 372              1
# 399              1
# 411              1
# 423              0
# 585              1
# 592              1
# 725              1
# 732              1
# 759              1
# 780              0
# 855              1

# %%
hf_subset[hf_subset["Cholesterol"]>=240]
# Out:
#      Age Sex Chest Pain Type  Resting Blood Pressure  Cholesterol  \
# 0     40   M             ATA                     140          289
# 2     37   M             ATA                     130          283
# 5     39   M             NAP                     120          339
# 9     48   F             ATA                     120          284
# 15    54   F             ATA                     120          273
# ..   ...  ..             ...                     ...          ...
# 900   58   M             ASY                     114          318
# 904   56   M             ATA                     120          240
# 906   55   F             ATA                     132          342
# 912   57   F             ASY                     140          241
# 913   45   M              TA                     110          264
#
#      Fasting Blood Sugar Resting ECG  Max Heart Rate Exercise Angina  \
# 0                      0      Normal             172               N
# 2                      0          ST              98               N
# 5                      0      Normal             170               N
# 9                      0      Normal             120               N
# 15                     0      Normal             150               N
# ..                   ...         ...             ...             ...
# 900                    0          ST             140               N
# 904                    0      Normal             169               N
# 906                    0      Normal             166               N
# 912                    0      Normal             123               Y
# 913                    0      Normal             132               N
#
#      Heart Disease
# 0                0
# 2                0
# 5                0
# 9                0
# 15               0
# ..             ...
# 900              1
# 904              0
# 906              0
# 912              1
# 913              1
#
# [363 rows x 10 columns]

# %%
df = pd.read_csv("heart.csv")
df.head(20)
# Out:
#     Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0    40   M           ATA        140          289          0     Normal
# 1    49   F           NAP        160          180          0     Normal
# 2    37   M           ATA        130          283          0         ST
# 3    48   F           ASY        138          214          0     Normal
# 4    54   M           NAP        150          195          0     Normal
# 5    39   M           NAP        120          339          0     Normal
# 6    45   F           ATA        130          237          0     Normal
# 7    54   M           ATA        110          208          0     Normal
# 8    37   M           ASY        140          207          0     Normal
# 9    48   F           ATA        120          284          0     Normal
# 10   37   F           NAP        130          211          0     Normal
# 11   58   M           ATA        136          164          0         ST
# 12   39   M           ATA        120          204          0     Normal
# 13   49   M           ASY        140          234          0     Normal
# 14   42   F           NAP        115          211          0         ST
# 15   54   F           ATA        120          273          0     Normal
# 16   38   M           ASY        110          196          0     Normal
# 17   43   F           ATA        120          201          0     Normal
# 18   60   M           ASY        100          248          0     Normal
# 19   36   M           ATA        120          267          0     Normal
#
#     MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0     172              N      0.0       Up             0
# 1     156              N      1.0     Flat             1
# 2      98              N      0.0       Up             0
# 3     108              Y      1.5     Flat             1
# 4     122              N      0.0       Up             0
# 5     170              N      0.0       Up             0
# 6     170              N      0.0       Up             0
# 7     142              N      0.0       Up             0
# 8     130              Y      1.5     Flat             1
# 9     120              N      0.0       Up             0
# 10    142              N      0.0       Up             0
# 11     99              Y      2.0     Flat             1
# 12    145              N      0.0       Up             0
# 13    140              Y      1.0     Flat             1
# 14    137              N      0.0       Up             0
# 15    150              N      1.5     Flat             0
# 16    166              N      0.0     Flat             1
# 17    165              N      0.0       Up             0
# 18    125              N      1.0     Flat             1
# 19    160              N      3.0     Flat             1

# %%
cp_type = set(df.ChestPainType.values)
print(cp_type)

#
#
# Out:
# {'ASY', 'TA', 'NAP', 'ATA'}

# %%
df['HeartDisease'].value_counts()
# Out:
# 1    508
# 0    410
# Name: HeartDisease, dtype: int64

# %%
# Selecting Heart Disease data equals to 1 
df = df.loc[df['HeartDisease'] == 1]
df['HeartDisease'].value_counts()
# Out:
# 1    508
# Name: HeartDisease, dtype: int64

# %%
# Delete the Heart Disease column 
df = df.drop('HeartDisease', axis=1)
df.head()
# Out:
#     Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 1    49   F           NAP        160          180          0     Normal
# 3    48   F           ASY        138          214          0     Normal
# 8    37   M           ASY        140          207          0     Normal
# 11   58   M           ATA        136          164          0         ST
# 13   49   M           ASY        140          234          0     Normal
#
#     MaxHR ExerciseAngina  Oldpeak ST_Slope
# 1     156              N      1.0     Flat
# 3     108              Y      1.5     Flat
# 8     130              Y      1.5     Flat
# 11     99              Y      2.0     Flat
# 13    140              Y      1.0     Flat

# %%
# # Look for the null values and remove from the data 
# df = df.dropna(axis=0, how='any')
# df.shape

# %%
df.RestingBP.sort_values()
# Out:
# 449      0
# 227     92
# 328     95
# 333     95
# 294     95
#       ...
# 759    192
# 241    200
# 399    200
# 732    200
# 365    200
# Name: RestingBP, Length: 508, dtype: int64

# %%
df = df[df['RestingBP'] >= 180]
len(df)
# Out:
# 13

# %%
# Create variable and columns with string values
X = pd.get_dummies(data=df, columns=['ChestPainType', 'RestingBP'])
print(X.shape)
X.head()
# Out:
# (13, 17)
#      Age Sex  Cholesterol  FastingBS RestingECG  MaxHR ExerciseAngina  \
# 123   58   F          393          0     Normal    110              Y
# 189   53   M          285          0         ST    120              Y
# 241   54   M          198          0     Normal    142              Y
# 365   64   F            0          0     Normal    140              Y
# 372   63   M            0          0     Normal     98              Y
#
#      Oldpeak ST_Slope  ChestPainType_ASY  ChestPainType_ATA  \
# 123      1.0     Flat                  0                  1
# 189      1.5     Flat                  1                  0
# 241      2.0     Flat                  1                  0
# 365      1.0     Flat                  1                  0
# 372      0.0       Up                  1                  0
#
#      ChestPainType_NAP  RestingBP_180  RestingBP_185  RestingBP_190  \
# 123                  0              1              0              0
# 189                  0              1              0              0
# 241                  0              0              0              0
# 365                  0              0              0              0
# 372                  0              0              1              0
#
#      RestingBP_192  RestingBP_200
# 123              0              0
# 189              0              0
# 241              0              1
# 365              0              1
# 372              0              0

# %%
# # Use standardscaler to standardize the data 
# scaler = StandardScaler()
# xscaled = scaler.fit_transform(X)
